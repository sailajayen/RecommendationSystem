# %%
# Multicolinearity - Variance Inflation Factor (VIF)
# Dealing with ID's
# Categorical Multicolinearity - Get dummies and run VIF
# Feature Selection - Random Forest feature importance

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import sklearn.metrics.pairwise as pw
from sklearn.metrics import mean_squared_error, accuracy_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load Data
df = pd.read_csv("RecommendationDataCleaned.csv",lineterminator='\n')

# %%
# Analyze
df.head()
# Out:
#    Customers.id Customers.fname Customers.lname  Customers.create_date  \
# 0           797         Christy            Dill             1426018724
# 1             3            John           Smith             1386089139
# 2             3            John           Smith             1386089139
# 3             4           James        Anderson             1386780263
# 4             5         Abraham          Pollak             1386861599
#
#    Customers.mailing  Customers.last_modified  Orders.id Orders.fname  \
# 0                1.0               1437764306       3758      Christy
# 1                1.0               1437764354         23         John
# 2                1.0               1437764354       9531         John
# 3                1.0               1437762646         29        James
# 4                0.0               1437764316         30      Abraham
#
#   Orders.lname Orders.order_number        ...         Products.packaging  \
# 0         Dill                3758        ...              1 Each / Each
# 1        Smith                  23        ...              1 Each / Each
# 2        Smith                9531        ...            800 Each / Case
# 3     Anderson                  29        ...              1 Each / Each
# 4       Pollak                  30        ...              1 Each / Each
#
#    Products.multiple  Products.upc  \
# 0               1 EA  8.223830e+11
# 1               1 EA  8.223830e+11
# 2               1 CS  8.223830e+11
# 3               1 EA  8.019675e+10
# 4               1 EA  8.223830e+11
#
#                                       Products.hcpcs Products.case_qty  \
# 0                                       E0149 +E0156                 1
# 1                                              A4357                 1
# 2  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION               800
# 3                                              A9270                 1
# 4                                              E0730                 1
#
#   Products.import_flags Products.shipping_length  Products.shipping_width  \
# 0                 136.0                    24.80                     7.50
# 1                   0.0                     8.00                     7.00
# 2                   0.0                    13.23                    10.04
# 3                   0.0                    10.60                     7.80
# 4                   0.0                     8.50                     2.75
#
#    Products.shipping_height Products.family_id
# 0                     30.40            PF61071
# 1                      1.50            PF02132
# 2                     10.24            PF00342
# 3                     18.50            PF04970
# 4                     12.00            PF03045
#
# [5 rows x 74 columns]

# %%
# Redo dtypes conversion

df[['Customers.mailing','Orders.shipping','Orders.payment_status','Orders.status','Products.vendor'\
    ,'Products.import_id','Products.flags','Products.taxable','Products.shopping_flags','Products.import_flags']]\
= \
df[['Customers.mailing','Orders.shipping','Orders.payment_status','Orders.status','Products.vendor'\
    ,'Products.import_id','Products.flags','Products.taxable','Products.shopping_flags','Products.import_flags']]\
    .apply(lambda x: x.astype('category'))


df['Products.case_qty'] = df['Products.case_qty'].astype('int')

# %%
# Del/transform columns
'''
Customers.id                     4194 non-null int64 # Del
Customers.fname                  4194 non-null object # Del
Customers.lname                  4194 non-null object # Del
Customers.create_date            4194 non-null int64 # Del
Customers.mailing                2114 non-null float64 # Convert to cat
Customers.last_modified          4194 non-null int64 # Del

Orders.id                        4194 non-null int64 # Del
Orders.fname                     4194 non-null object # Del
Orders.lname                     4194 non-null object # Del
Orders.order_number              4194 non-null object # Del
Orders.currency                  4194 non-null object 
Orders.subtotal                  4194 non-null float64 
Orders.shipping                  3999 non-null float64 # Convert to cat
Orders.total                     4194 non-null float64 
Orders.shipping_carrier          3577 non-null object 
Orders.shipping_method           3751 non-null object
Orders.tracking                  3818 non-null object # Del
Orders.payment_status            4189 non-null float64 # Convert to cat
Orders.payment_date              4176 non-null float64 # Del
Orders.payment_type              3810 non-null object 
Orders.payment_amount            4176 non-null float64
Orders.payment_id                3764 non-null object # Del
Orders.payment_code              3446 non-null object # Del
Orders.status                    4194 non-null int64 # Convert to cat
Orders.placed_date               4194 non-null int64 # Convert to Date
Orders.updated_date              4171 non-null float64 # Del
Orders.shipped_date              3848 non-null float64 # Del

Order_Items.id                   4194 non-null int64 # Del
Order_Items.qty                  4194 non-null int64 
Order_Items.price                4194 non-null float64 
Order_Items.cost                 4191 non-null float64 # Del

Products.id                      4037 non-null float64 # Del
Products.template                3973 non-null object 
Products.vendor                  4037 non-null float64 # convert to cat
Products.import_id               4037 non-null float64 # convert to cat
Products.name                    4037 non-null object 
Products.display_name            3662 non-null object # Del
Products.list_price              4017 non-null float64 
Products.flags                   2987 non-null float64 # convert to cat
Products.last_modified           4037 non-null float64 # Del
Products.taxable                 2959 non-null float64 # convert to cat
Products.shopping_gtin           3130 non-null float64 # Del - May be FE
Products.shopping_brand          4032 non-null object
Products.shopping_mpn            4034 non-null object
Products.shopping_flags          3917 non-null float64 # convert to cat
Products.amazon_asin             2935 non-null object
Products.amazon_item_type        4015 non-null object
Products.google_shopping_id      3780 non-null object
Products.google_shopping_type    3979 non-null object
Products.google_shopping_cat     4011 non-null object
Products.shopping_type           2334 non-null object
Products.pricegrabber_cat        2334 non-null object
Products.thefind_cat             2321 non-null object
Products.quickbooks_id           3728 non-null object
Products.qb_edit_sequence        3728 non-null float64 # Del - May be FE
Products.short_description       3015 non-null object 
Products.long_description        4008 non-null object # Del
Products.seo_title               4011 non-null object # Del
Products.seo_url                 4037 non-null object # Del
Products.unit                    3985 non-null object 
Products.packaging               2890 non-null object
Products.multiple                2964 non-null object
Products.upc                     2127 non-null float64 # Del - May be FE
Products.hcpcs                   3288 non-null object
Products.case_qty                2638 non-null float64 # convert to int
Products.import_flags            2786 non-null float64 # convert to cat
Products.shipping_length         3998 non-null float64 
Products.shipping_width          3998 non-null float64
Products.shipping_height         3998 non-null float64
Products.family_id               3869 non-null object # Del - May be FE
'''
# Out:
# '\nCustomers.id                     4194 non-null int64 # Del\nCustomers.fname                  4194 non-null object # Del\nCustomers.lname                  4194 non-null object # Del\nCustomers.create_date            4194 non-null int64 # Del\nCustomers.mailing                2114 non-null float64 # Convert to cat\nCustomers.last_modified          4194 non-null int64 # Del\n\nOrders.id                        4194 non-null int64 # Del\nOrders.fname                     4194 non-null object # Del\nOrders.lname                     4194 non-null object # Del\nOrders.order_number              4194 non-null object # Del\nOrders.currency                  4194 non-null object \nOrders.subtotal                  4194 non-null float64 \nOrders.shipping                  3999 non-null float64 # Convert to cat\nOrders.total                     4194 non-null float64 \nOrders.shipping_carrier          3577 non-null object \nOrders.shipping_method           3751 non-null object\nOrders.tracking                  3818 non-null object # Del\nOrders.payment_status            4189 non-null float64 # Convert to cat\nOrders.payment_date              4176 non-null float64 # Del\nOrders.payment_type              3810 non-null object \nOrders.payment_amount            4176 non-null float64\nOrders.payment_id                3764 non-null object # Del\nOrders.payment_code              3446 non-null object # Del\nOrders.status                    4194 non-null int64 # Convert to cat\nOrders.placed_date               4194 non-null int64 # Convert to Date\nOrders.updated_date              4171 non-null float64 # Del\nOrders.shipped_date              3848 non-null float64 # Del\n\nOrder_Items.id                   4194 non-null int64 # Del\nOrder_Items.qty                  4194 non-null int64 \nOrder_Items.price                4194 non-null float64 \nOrder_Items.cost                 4191 non-null float64 # Del\n\nProducts.id                      4037 non-null float64 # Del\nProducts.template                3973 non-null object \nProducts.vendor                  4037 non-null float64 # convert to cat\nProducts.import_id               4037 non-null float64 # convert to cat\nProducts.name                    4037 non-null object \nProducts.display_name            3662 non-null object # Del\nProducts.list_price              4017 non-null float64 \nProducts.flags                   2987 non-null float64 # convert to cat\nProducts.last_modified           4037 non-null float64 # Del\nProducts.taxable                 2959 non-null float64 # convert to cat\nProducts.shopping_gtin           3130 non-null float64 # Del - May be FE\nProducts.shopping_brand          4032 non-null object\nProducts.shopping_mpn            4034 non-null object\nProducts.shopping_flags          3917 non-null float64 # convert to cat\nProducts.amazon_asin             2935 non-null object\nProducts.amazon_item_type        4015 non-null object\nProducts.google_shopping_id      3780 non-null object\nProducts.google_shopping_type    3979 non-null object\nProducts.google_shopping_cat     4011 non-null object\nProducts.shopping_type           2334 non-null object\nProducts.pricegrabber_cat        2334 non-null object\nProducts.thefind_cat             2321 non-null object\nProducts.quickbooks_id           3728 non-null object\nProducts.qb_edit_sequence        3728 non-null float64 # Del - May be FE\nProducts.short_description       3015 non-null object \nProducts.long_description        4008 non-null object # Del\nProducts.seo_title               4011 non-null object # Del\nProducts.seo_url                 4037 non-null object # Del\nProducts.unit                    3985 non-null object \nProducts.packaging               2890 non-null object\nProducts.multiple                2964 non-null object\nProducts.upc                     2127 non-null float64 # Del - May be FE\nProducts.hcpcs                   3288 non-null object\nProducts.case_qty                2638 non-null float64 # convert to int\nProducts. ...

# %%
# Del id's, redundant columns, unnwanted dates
df = df.drop(['Customers.fname','Customers.lname','Customers.create_date','Customers.last_modified','Orders.id'
             ,'Orders.fname','Orders.lname','Orders.order_number','Orders.tracking','Orders.payment_date'
             ,'Orders.payment_id','Orders.payment_code','Orders.updated_date','Orders.shipped_date','Order_Items.id','Order_Items.product_id'
             ,'Order_Items.price','Order_Items.cost','Products.display_name','Products.last_modified','Products.shopping_gtin'
             ,'Products.qb_edit_sequence','Products.long_description','Products.seo_title','Products.seo_url'
             ,'Products.upc','Products.family_id','Products.quickbooks_id','Order_Items.product_name'
             ,'Products.shopping_mpn','Products.amazon_asin','Products.google_shopping_id'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4194 entries, 0 to 4193
# Data columns (total 42 columns):
# Customers.id                     4194 non-null int64
# Customers.mailing                4194 non-null category
# Orders.currency                  4194 non-null object
# Orders.subtotal                  4194 non-null float64
# Orders.shipping                  4194 non-null category
# Orders.total                     4194 non-null float64
# Orders.shipping_carrier          4194 non-null object
# Orders.shipping_method           4194 non-null object
# Orders.payment_status            4194 non-null category
# Orders.payment_type              4194 non-null object
# Orders.payment_amount            4194 non-null float64
# Orders.status                    4194 non-null category
# Orders.placed_date               4194 non-null int64
# Order_Items.qty                  4194 non-null int64
# Products.id                      4194 non-null float64
# Products.template                4194 non-null object
# Products.vendor                  4194 non-null category
# Products.import_id               4194 non-null category
# Products.name                    4194 non-null object
# Products.list_price              4194 non-null float64
# Products.price                   4194 non-null float64
# Products.cost                    4194 non-null float64
# Products.flags                   4194 non-null category
# Products.taxable                 4194 non-null category
# Products.shopping_brand          4194 non-null object
# Products.shopping_flags          4194 non-null category
# Products.amazon_item_type        4194 non-null object
# Products.google_shopping_type    4194 non-null object
# Products.google_shopping_cat     4194 non-null object
# Products.shopping_type           4194 non-null object
# Products.pricegrabber_cat        4194 non-null object
# Products.thefind_cat             4194 non-null object
# Products.short_description       4194 non-null object
# Products.unit                    4194 non-null object
# Products.packaging               4194 non-null object
# Products.multiple                4194 non-null object
# Products.hcpcs                   4194 non-null object
# Products.case_qty                4194 non-null int64
# Products.import_flags            4194 non-null category
# Products.shipping_length         4194 non-null float64
# Products.shipping_width          4194 non-null float64
# Products.shipping_height         4194 non-null float64
# dtypes: category(10), float64(10), int64(4), object(18)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#    Customers.id Customers.mailing Orders.currency  Orders.subtotal  \
# 0           797               1.0             USD            57.20
# 1             3               1.0             USD            20.00
# 2             3               1.0             USD            68.78
# 3             4               1.0             USD            19.56
# 4             5               0.0             USD            36.05
#
#   Orders.shipping  Orders.total Orders.shipping_carrier  \
# 0            9.95         64.29                   fedex
# 1            9.99         29.99                   fedex
# 2            9.95         78.73                  manual
# 3            9.95         29.55                   fedex
# 4            9.95         46.00                   fedex
#
#   Orders.shipping_method Orders.payment_status Orders.payment_type  \
# 0              11|Ground                   3.0       authorize.net
# 1              11|Ground                   3.0       authorize.net
# 2    0|Standard Shipping                   3.0       authorize.net
# 3              11|Ground                   3.0       authorize.net
# 4              11|Ground                   3.0       authorize.net
#
#              ...                           Products.short_description  \
# 0            ...                        ROLLATOR,BASIC,STEEL,6",GREEN
# 1            ...              BAG,DRAINAGE,UROLOGY,2000ML,ANTI REFLUX
# 2            ...             GLOVE,EXAM,NITRILE,BLUE,FINGRTIP,TXT,XXL
# 3            ...                      BASKET,WALKER,FOR 2 BUTTON WALK
# 4            ...                   DEVICE,TENS UNIT,TENS 1000,DUAL CH
#
#   Products.unit  Products.packaging  Products.multiple  \
# 0            EA       1 Each / Each               1 EA
# 1            EA       1 Each / Each               1 EA
# 2            CS     800 Each / Case               1 CS
# 3            EA       1 Each / Each               1 EA
# 4            EA       1 Each / Each               1 EA
#
#                                       Products.hcpcs Products.case_qty  \
# 0                                       E0149 +E0156                 1
# 1                                              A4357                 1
# 2  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION               800
# 3                                              A9270                 1
# 4                                              E0730                 1
#
#   Products.import_flags Products.shipping_length Products.shipping_width  \
# 0                 136.0                    24.80                    7.50
# 1                   0.0                     8.00                    7.00
# 2                   0.0                    13.23                   10.04
# 3                   0.0                    10.60                    7.80
# 4                   0.0                     8.50                    2.75
#
#    Products.shipping_height
# 0                     30.40
# 1                      1.50
# 2                     10.24
# 3                     18.50
# 4                     12.00
#
# [5 rows x 42 columns]

# %%
# Multicolinearity - Variance Inflation Factor (VIF)

X_vif = add_constant(df._get_numeric_data())
pd.Series([variance_inflation_factor(X_vif.values, i) 
               for i in range(X_vif.shape[1])], 
              index=X_vif.columns)
# Out:
# const                       29260.556159
# Customers.id                    4.968144
# Orders.subtotal               180.035845
# Orders.total                  182.027544
# Orders.payment_amount          16.445069
# Orders.placed_date              4.806273
# Order_Items.qty                 1.263020
# Products.id                     1.286114
# Products.list_price             6.503071
# Products.price                 49.584334
# Products.cost                  43.839952
# Products.case_qty               1.035784
# Products.shipping_length        1.820206
# Products.shipping_width         1.542822
# Products.shipping_height        1.699943
# dtype: float64

# %%
# Drop Orders.subtotal, Order_Items.cost, Orders.payment_amount, Products.list_price
df.drop(['Orders.subtotal','Orders.payment_amount','Products.list_price','Products.cost'],axis=1, inplace = True)

# %%
X_vif = add_constant(df._get_numeric_data())
pd.Series([variance_inflation_factor(X_vif.values, i) 
               for i in range(X_vif.shape[1])], 
              index=X_vif.columns)
# Out:
# const                       29120.072470
# Customers.id                    4.918730
# Orders.total                    1.523537
# Orders.placed_date              4.782038
# Order_Items.qty                 1.238597
# Products.id                     1.282068
# Products.price                  1.757888
# Products.case_qty               1.033076
# Products.shipping_length        1.806407
# Products.shipping_width         1.449179
# Products.shipping_height        1.449443
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4194 entries, 0 to 4193
# Data columns (total 38 columns):
# Customers.id                     4194 non-null int64
# Customers.mailing                4194 non-null category
# Orders.currency                  4194 non-null object
# Orders.shipping                  4194 non-null category
# Orders.total                     4194 non-null float64
# Orders.shipping_carrier          4194 non-null object
# Orders.shipping_method           4194 non-null object
# Orders.payment_status            4194 non-null category
# Orders.payment_type              4194 non-null object
# Orders.status                    4194 non-null category
# Orders.placed_date               4194 non-null int64
# Order_Items.qty                  4194 non-null int64
# Products.id                      4194 non-null float64
# Products.template                4194 non-null object
# Products.vendor                  4194 non-null category
# Products.import_id               4194 non-null category
# Products.name                    4194 non-null object
# Products.price                   4194 non-null float64
# Products.flags                   4194 non-null category
# Products.taxable                 4194 non-null category
# Products.shopping_brand          4194 non-null object
# Products.shopping_flags          4194 non-null category
# Products.amazon_item_type        4194 non-null object
# Products.google_shopping_type    4194 non-null object
# Products.google_shopping_cat     4194 non-null object
# Products.shopping_type           4194 non-null object
# Products.pricegrabber_cat        4194 non-null object
# Products.thefind_cat             4194 non-null object
# Products.short_description       4194 non-null object
# Products.unit                    4194 non-null object
# Products.packaging               4194 non-null object
# Products.multiple                4194 non-null object
# Products.hcpcs                   4194 non-null object
# Products.case_qty                4194 non-null int64
# Products.import_flags            4194 non-null category
# Products.shipping_length         4194 non-null float64
# Products.shipping_width          4194 non-null float64
# Products.shipping_height         4194 non-null float64
# dtypes: category(10), float64(6), int64(4), object(18)
# memory usage: 964.4+ KB

# %%
# Categorical Multicoliarity
df.select_dtypes(include=['category','object']).columns
# Out:
# Index(['Customers.mailing', 'Orders.currency', 'Orders.shipping',
#        'Orders.shipping_carrier', 'Orders.shipping_method',
#        'Orders.payment_status', 'Orders.payment_type', 'Orders.status',
#        'Products.template', 'Products.vendor', 'Products.import_id',
#        'Products.name', 'Products.flags', 'Products.taxable',
#        'Products.shopping_brand', 'Products.shopping_flags',
#        'Products.amazon_item_type', 'Products.google_shopping_type',
#        'Products.google_shopping_cat', 'Products.shopping_type',
#        'Products.pricegrabber_cat', 'Products.thefind_cat',
#        'Products.short_description', 'Products.unit', 'Products.packaging',
#        'Products.multiple', 'Products.hcpcs', 'Products.import_flags'],
#       dtype='object')

# %%
df.select_dtypes(include=['category','object']).nunique()
# Out:
# Customers.mailing                   2
# Orders.currency                     1
# Orders.shipping                    53
# Orders.shipping_carrier            11
# Orders.shipping_method             14
# Orders.payment_status               3
# Orders.payment_type                 5
# Orders.status                      10
# Products.template                   2
# Products.vendor                     8
# Products.import_id                 10
# Products.name                    1391
# Products.flags                      9
# Products.taxable                    2
# Products.shopping_brand           101
# Products.shopping_flags             7
# Products.amazon_item_type           1
# Products.google_shopping_type     313
# Products.google_shopping_cat        5
# Products.shopping_type              1
# Products.pricegrabber_cat           1
# Products.thefind_cat                1
# Products.short_description       1008
# Products.unit                      20
# Products.packaging                195
# Products.multiple                  14
# Products.hcpcs                    201
# Products.import_flags              21
# dtype: int64

# %%
df[['Products.name','Products.short_description','Products.template','Products.unit','Products.hcpcs']]
# Out:
#                                           Products.name  \
# 0                           Basic Steel Rollators,Green
# 1                                    Urinary Drain Bags
# 2           SensiCare Nitrile Exam Gloves,Blue,XX-Large
# 3                           Basket for 2-Button Walkers
# 4                                 TENS 3000 Analog Unit
# 5                            Emesis Bags,Blue,36.000 OZ
# 6                            Emesis Bags,Blue,36.000 OZ
# 7     Aloetouch Sensitive Personal Cleansing Baby Wipes
# 8                          Universal Raised Toilet Seat
# 9                            Emesis Bags,Blue,36.000 OZ
# 10                           Emesis Bags,Blue,36.000 OZ
# 11          Multipurpose Sharps Containers,Red,8.000 QT
# 12    Protection Plus Disposable Underpads,Blue,36" ...
# 13    Aloetouch SELECT Premium Spunlace Personal Cle...
# 14    Aloetouch SELECT Premium Spunlace Personal Cle...
# 15                           Emesis Bags,Blue,36.000 OZ
# 16                           Emesis Bags,Blue,36.000 OZ
# 17    Aluminum Transport Chair with 12" Wheels,Blue,...
# 18                           Emesis Bags,Blue,36.000 OZ
# 19                         Ultrasound Gel,Blue,8.500 OZ
# 20    ReadyBath SELECT Medium Weight Cleansing Washc...
# 21    ReadyBath SELECT Medium Weight Cleansing Washc...
# 22    Protection Plus Disposable Underpads,Blue,24" ...
# 23    ReadyBath SELECT Medium Weight Cleansing Washc...
# 24    Aloetouch SELECT Premium Spunlace Personal Cle...
# 25                           Emesis Bags,Blue,36.000 OZ
# 26                           Emesis Bags,Blue,36.000 OZ
# 27    Aloetouch SELECT Premium Spunlace Personal Cle...
# 28    Aloetouch SELECT Premium Spunlace Personal Cle...
# 29    Aloetouch SELECT Premium Spunlace Personal Cle...
# ...                                                 ...
# 4164    Molded AFO orthosis, left, large/x-large M 8-12
# 4165                        Silent Knight Pill Crushers
# 4166                 Silent Knight Pill Crusher Pouches
# 4167  Washable Cotton Material Gait Belts,Red, White...
# 4168                        Unisex Zip Front Smock,Navy
# 4169                  Unisex Zip Front Smock,Light Blue
# 4170                 Pediatric Folding Walkers,Green,5"
# 4171                     Bottom Buddy toilet tissue aid
# 4172    Remedy Basics Moisturizing Body Lotion,4.000 OZ
# 4173  CanDo&reg; Soft Pliable Medicine Ball - 5" Dia...
# 4174               CarraScent Odor Eliminators,8.000 OZ
# 4175          Phlebotomy Sharps Containers,Red,1.000 QT
# 4176  CanDo&reg; Foam Roller - White PE foam - 6" x ...
# 4177                                Toilet Safety Rails
# 4178  Med Aire Alternating Pressure Pump and Pad System
# 4179  The Original Cuff&reg; Ankle and Wrist Weight ...
# 4180      Baseline&reg; Dolorimeter - 22 pound Capacity
# 4181  Protection Plus Overnight Protective Underwear...
# 4182                     Tri-Wheeled Rollators,Titanium
# 4183                                 Commode Seat & Lid
# 4184  SensiCare Ice Blue Nitrile Exam Gloves,Violet ...
# 4185  Relief Pak&reg; HotSpot&reg; Moist Heat Pack -...
# 4186  Relief Pak&reg; HotSpot&reg; Moist Heat Pack -...
# 4187  Relief Pak&reg; HotSpot&reg; Moist Heat Pack -...
# 4188                                 Commode Seat & Lid
# 4189                         Emesis Bags,Blue,36.000 OZ
# 4190                                     Bed Assist Bar
# 4191  Spitfire EX Compact Travel Power Mobility Scoo...
# 4192  Standard Bariatric Heavy Duty Rollator,Burgund...
# 4193            Medline Sterile Alcohol Prep Pads,Large
#
#                     Products.short_description        Products.template  \
# 0                ROLLATOR,BASIC,STEEL,6",GREEN  sub-product-detail.html
# 1      BAG,DRAINAGE,UROLOGY,2000ML,ANTI REFLUX  sub-product-detail.html
# 2     GLOVE,EXAM,NITRILE,BLUE,FINGRTIP,TXT,XXL  sub-product-detail.html
# 3              BASKET,WALKER,FOR 2 BUTTON WALK  sub-product-detail.html
# 4           DEVICE,TENS UNIT,TENS 1000,DUAL CH  sub-product-detail.html
# 5      BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 6      BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 7     WIPE, BABY, ALOETOUCH, SENSITIVE, FRAG F  sub-product-detail.html
# 8                 SEAT,TOILET,RAISED,UNIVERSAL  sub-product-detail.html
# 9      BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 10     BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 11       CONTAINER,SHARPS,2 GAL.,RED,WALL/FREE  sub-product-detail.html
# 12        UNDERPAD,FLUFF,DLUX,PROT PLUS,23X36"  sub-product-detail.html
# 13     WIPE, ALOETOUCH, SELECT, SCENTED, 48/TU  sub-product-detail.html
# 14     WIPE, ALOETOUCH, SELECT, SCENTED, 48/TU  sub-product-detail.html
# 15     BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 16     BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 17     TRANSPORT CHAIR,ALUM, BASIC,12"WHL,BLUE  sub-product-detail.html
# 18     BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 19        GEL,ULTRASOUND,8.5 OZ,SQUEEZE BOTTLE  sub-product-detail.html
# 20            READYBATH, SELECT, SCENTED, 8/PK  sub-product-detail.html
# 21    READYBATH, SELECT, ANTIBAC, SCENTED, 8/P  sub-product-detail.html
# 22            UNDERPAD,ECON,DISP,17"X24",25/BG  sub-product-detail.html
# 23            READYBATH, SELECT, SCENTED, 8/PK  sub-product-detail.html
# 24     WIPE, ALOETOUCH, SELECT, SCENTED, 48/PK  sub-product-detail.html
# 25     BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 26     BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 27     WIPE, ALOETOUCH, SELECT, SCENTED, 64/PK  sub-product-detail.html
# 28     WIPE, ALOETOUCH, SELECT, SCENTED, 64/PK  sub-product-detail.html
# 29     WIPE, ALOETOUCH, SELECT, SCENTED, 64/PK  sub-product-detail.html
# ...                                        ...                      ...
# 4164   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4165                CRUSHER,PILL,SILENT KNIGHT  sub-product-detail.html
# 4166      POUCH,MEDICATION,PILL,F/PILL CRUSHER  sub-product-detail.html
# 4167   BELT,TRANSFER,COTTN,W/BUCK,PINST,60",6C  sub-product-detail.html
# 4168            SMOCK,UNISEX,ZIP FRONT,NAVY,XL  sub-product-detail.html
# 4169         SMOCK,UNISEX,ZIP FRONT,LT BLUE,XL  sub-product-detail.html
# 4170                    WALKER,STRIDER,TWEENER  sub-product-detail.html
# 4171   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4172         LOTION, REMEDY, UNSC, 4OZ FLIPCAP  sub-product-detail.html
# 4173   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4174       ELIMINATOR,ODOR,CARRASCENT,8OZ,PUMP  sub-product-detail.html
# 4175         CONTAINER,SHARPS,1 QT.,RED,PHLEB.  sub-product-detail.html
# 4176   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4177   RAIL,TOILET ,SAFETY, 1/CS,BULK,GUARDIAN  sub-product-detail.html
# 4178   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4179   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4180   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4181        UNDERWEAR,PROTECTIVE,LG,HVY,40-56"  sub-product-detail.html
# 4182       WALKER,GUARDIAN,ROLLING,TRI-WHEELED  sub-product-detail.html
# 4183     REPLACEMENT,SEAT/LID,COMMODE,MDS89664  sub-product-detail.html
# 4184  GLOVE,EXAM,NITRILE,SENSICARE-ICE,BLUE,MD  sub-product-detail.html
# 4185   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4186   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4187   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4188     REPLACEMENT,SEAT/LID,COMMODE,MDS89664  sub-product-detail.html
# 4189   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4190                            BAR,BED ASSIST  sub-product-detail.html
# 4191   BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK  sub-product-detail.html
# 4192     ROLLATOR, X-WIDE,HEAVY DUTY, 400 LBS.  sub-product-detail.html
# 4193      PAD,PREP,ALCOHOL,LARGE,2-PLY,STERILE  sub-product-detail.html
#
#      Products.unit                                     Products.hcpcs
# 0               EA                                       E0149 +E0156
# 1               EA                                              A4357
# 2               CS  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION
# 3               EA                                              A9270
# 4               EA                                              E0730
# 5               EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 6               EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 7               CS  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 8               EA                                              E0244
# 9               EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 10              EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 11              EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 12              CS  NOT COVERED BY MEDICARE - CHECK REIMBURSEMENT ...
# 13              CS  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 14              CS  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 15              EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 16              EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 17              CS                                              E1038
# 18              EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 19              EA  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION
# 20              CS  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 21              CS  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 22              CS  NOT COVERED BY MEDICARE - CHECK REIMBURSEMENT ...
# 23              CS  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 24              CS  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 25              EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 26              EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 27              PK  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 28              PK  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 29              PK  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# ...            ...                                                ...
# 4164            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4165            EA  SEE WWW.DMEPDAC.COM - CHECK "MISC" KEYWORD COD...
# 4166            BX  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4167            CS  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION
# 4168            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4169            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4170            EA                                              E0143
# 4171            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4172            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4173            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4174            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4175            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4176            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4177            EA                                              E0243
# 4178            EA                                              E0181
# 4179            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4180            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4181            CS  NOT COVERED BY MEDICARE - CHECK REIMBURSEMENT ...
# 4182            EA  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION
# 4183            EA                                              A9999
# 4184            BX  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION
# 4185            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4186            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4187            EA  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4188            EA                                              A9999
# 4189            PK  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...
# 4190            EA  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION
# 4191            EA                                              K0800
# 4192            EA                                              E0149
# 4193            BX                                              A4245
#
# [4194 rows x 5 columns]

# %%
df.shape
# Out:
# (4194, 38)

# %%
x = pd.get_dummies(df, drop_first=True)

# %%
x.shape
# Out:
# (4194, 3392)

# %%
X = x.drop('Order_Items.qty', axis=1)
y = x['Order_Items.qty']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.8, random_state=0)
# Out:
# /Users/HS/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
#Random Forest
clf = RandomForestRegressor(n_estimators=20)
clf = clf.fit(X_train,y_train)
clfpred = clf.predict(X_train)
print(mean_squared_error(y_train,clfpred))
# Out:
# 20.759817623

# %%
clfpredtest = clf.predict(X_test)
print(mean_squared_error(y_test,clfpredtest))
# Out:
# 3.7284840584

# %%
# Feature Importance
feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(X.columns, clf.feature_importances_):
    feats[feature] = importance #add the name/value pair 

importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-importance'})
importances.sort_values(by='Gini-importance',ascending=False)
# Out:
#                                                     Gini-importance
# Orders.total                                               0.313135
# Orders.status_8                                            0.228673
# Products.name_Sanitary Pads with Adhesive & Wings          0.052393
# Products.google_shopping_type_Wheelchairs > Man...         0.047617
# Products.packaging_10 Each / Case                          0.040743
# Products.price                                             0.039312
# Products.google_shopping_type_Exam & Diagnostic...         0.038025
# Products.shipping_height                                   0.030359
# Products.name_Disposable Emergency Blanket,Not ...         0.029124
# Products.name_Emesis Bags,Blue,36.000 OZ                   0.025734
# Products.packaging_1 Each / Each                           0.022967
# Products.name_Phlebotomy Sharps Containers,Red,...         0.022475
# Products.id                                                0.011725
# Orders.shipping_method_SOUTHWESTERN MOTOR TRNAS            0.008917
# Orders.placed_date                                         0.008631
# Products.google_shopping_type_Patient Room And ...         0.007115
# Products.short_description_BLANKET,EMERGENCY,PO...         0.006833
# Products.case_qty                                          0.005754
# Products.shipping_width                                    0.004266
# Customers.id                                               0.004236
# Products.short_description_TUBING,CORRUGATED,PO...         0.003447
# Products.short_description_PAD,SANITARY,11 IN,M...         0.003156
# Products.flags_32896.0                                     0.003138
# Products.short_description_WIPE, ALOETOUCH, PRO...         0.002727
# Products.name_Deluxe Automatic Blood Pressure M...         0.002723
# Products.google_shopping_type_Personal Care > F...         0.002460
# Orders.shipping_method_NATIONAL DELIVERY                   0.002067
# Products.short_description_LOTION, REMEDY, UNSC...         0.001509
# Products.packaging_20 Each / Bag                           0.001429
# Products.packaging_8000 Each / Case                        0.001418
# ...                                                             ...
# Products.name_First Class School Chair Anti-Tip...         0.000000
# Products.google_shopping_type_Personal Care > B...         0.000000
# Products.name_First Class School Chair                     0.000000
# Products.name_Fingertip Pulse Oximeter                     0.000000
# Products.google_shopping_type_Personal Care > O...         0.000000
# Products.google_shopping_type_Personal Care > O...         0.000000
# Products.name_Finger and shoulder ladder - Plas...         0.000000
# Products.google_shopping_type_Personal Care > O...         0.000000
# Products.google_shopping_type_Personal Care > P...         0.000000
# Products.google_shopping_type_Personal Care > P...         0.000000
# Products.google_shopping_type_Personal Care > P...         0.000000
# Products.name_First Class School Chair Multi-Ax...         0.000000
# Products.google_shopping_type_Pediatric > Pedia...         0.000000
# Products.google_shopping_type_Pediatric > Pedia...         0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.name_FitRight Restore Briefs,48"-58"              0.000000
# Products.name_FitRight Restore Briefs,32"-42"              0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.name_FitRight Pink Protective Underwea...         0.000000
# Products.google_shopping_type_Pediatric > Pedia...         0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.name_FitRight Basic Brief,40"-50"                 0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.name_First Class School Chair Support Kit         0.000000
# Products.google_shopping_type_Patient Room And ...         0.000000
# Products.google_shopping_type_Exam & Diagnostic...         0.000000
#
# [3391 rows x 1 columns]

# %%
# Top features
Orders.total
Orders.status
Products.name
Products.google_shopping_type
Products.packaging
Products.price
Products.shipping_height
Orders.shipping_method
Orders.placed_date
Products.short_description
Products.case_qty
